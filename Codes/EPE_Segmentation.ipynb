# %%
from nltk.tag.stanford import StanfordNERTagger
from nltk.tokenize import word_tokenize, sent_tokenize
import nltk
from transformers import pipeline
import pandas as pd


# !wget 'https://nlp.stanford.edu/software/stanford-ner-2018-10-16.zip'
# !unzip stanford-ner-2018-10-16.zip

nltk.download('punkt')

st = StanfordNERTagger('/content/stanford-ner-2018-10-16/classifiers/english.all.3class.distsim.crf.ser.gz',
                       '/content/stanford-ner-2018-10-16/stanford-ner.jar',
                       encoding='utf-8')

# text = 'While in France, Christine Lagarde discussed short-term stimulus efforts in a recent interview with the Wall Street Journal.'

# tokenized_text = word_tokenize(text)
# classified_text = st.tag(tokenized_text)
# print(classified_text)

# Initialize the emotion classification pipeline
emotion_classifier = pipeline('text-classification', model='j-hartmann/emotion-english-distilroberta-base')

def extract_entities(sentence):
    tokenized_sentence = word_tokenize(sentence)
    tagged_sentence = st.tag(tokenized_sentence)
    entities = {"PERSON": set(), "ORGANIZATION": set(), "LOCATION": set()}
    for word, tag in tagged_sentence:
        if tag in entities:
            entities[tag].add(word)
    return tagged_sentence, entities

def truncate_sentence(sentence, max_length=510):
    tokens = word_tokenize(sentence)
    if len(tokens) > max_length:
        tokens = tokens[:max_length]
    return ' '.join(tokens)

def segment_poem_by_entities_and_emotion(poem):
    sentences = sent_tokenize(poem)

    segments = []
    segment_entities = []
    segment_emotions = []
    current_segment = []
    prev_entities = {"PERSON": set(), "ORGANIZATION": set(), "LOCATION": set()}
    prev_emotion = None

    for sentence in sentences:
        sentence = truncate_sentence(sentence)
        tagged_sentence, current_entities = extract_entities(sentence)
        emotion = emotion_classifier(sentence)[0]
        current_emotion = emotion['label']

        print(f"Sentence: {sentence}")
        print(f"NER Tags: {tagged_sentence}")
        print(f"Emotion: {current_emotion} (Score: {emotion['score']:.2f})")
        print()

        if current_emotion != prev_emotion:
            if current_segment:
                segments.append(" ".join(current_segment))
                segment_entities.append(prev_entities)
                segment_emotions.append(prev_emotion)
            current_segment = [sentence]
            prev_entities = current_entities
            prev_emotion = current_emotion
        else:
            if (not current_entities["PERSON"] and not current_entities["ORGANIZATION"] and not current_entities["LOCATION"]):
                current_segment.append(sentence)
            elif ((current_entities["PERSON"] and current_entities["PERSON"] != prev_entities["PERSON"]) or
                  (current_entities["ORGANIZATION"] and current_entities["ORGANIZATION"] != prev_entities["ORGANIZATION"]) or
                  (current_entities["LOCATION"] and current_entities["LOCATION"] != prev_entities["LOCATION"])):
                if current_segment:
                    segments.append(" ".join(current_segment))
                    segment_entities.append(prev_entities)
                    segment_emotions.append(prev_emotion)
                current_segment = [sentence]
                prev_entities = current_entities
                prev_emotion = current_emotion
            else:
                current_segment.append(sentence)

    if current_segment:
        segments.append(" ".join(current_segment))
        segment_entities.append(prev_entities)
        segment_emotions.append(prev_emotion)

    print(segments)
    print()
    print(segment_entities)
    print()
    print(segment_emotions)

    return segments, segment_entities, segment_emotions











# def segment_poem_by_entities_and_emotion1(poem):
#     sentences = sent_tokenize(poem)

#     segments = []
#     current_segment = []
#     current_entities = {"PERSON": set(), "ORGANIZATION": set(), "LOCATION": set()}
#     current_emotion = None

#     for sentence in sentences:
#         tagged_sentence, new_entities = extract_entities(sentence)
#         emotion = emotion_classifier(sentence)[0]
#         new_emotion = emotion['label']

#         print(f"Sentence: {sentence}")
#         print(f"NER Tags: {tagged_sentence}")
#         print(f"Emotion: {new_emotion} (Score: {emotion['score']:.2f})")
#         print()

#         if (new_entities["PERSON"] != current_entities["PERSON"] or
#             new_entities["ORGANIZATION"] != current_entities["ORGANIZATION"] or
#             new_entities["LOCATION"] != current_entities["LOCATION"] or
#             new_emotion != current_emotion):
#             if current_segment:
#                 segments.append(" ".join(current_segment))
#             current_segment = [sentence]
#             current_entities = new_entities
#             current_emotion = new_emotion
#         else:
#             current_segment.append(sentence)

#     if current_segment:
#         segments.append(" ".join(current_segment))

#     return segments
# Out:
# --2024-07-31 11:48:52--  https://nlp.stanford.edu/software/stanford-ner-2018-10-16.zip
# Resolving nlp.stanford.edu (nlp.stanford.edu)... 171.64.67.140
# Connecting to nlp.stanford.edu (nlp.stanford.edu)|171.64.67.140|:443... connected.
# HTTP request sent, awaiting response... 302 FOUND
# Location: https://downloads.cs.stanford.edu/nlp/software/stanford-ner-2018-10-16.zip [following]
# --2024-07-31 11:48:53--  https://downloads.cs.stanford.edu/nlp/software/stanford-ner-2018-10-16.zip
# Resolving downloads.cs.stanford.edu (downloads.cs.stanford.edu)... 171.64.64.22
# Connecting to downloads.cs.stanford.edu (downloads.cs.stanford.edu)|171.64.64.22|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 180358328 (172M) [application/zip]
# Saving to: ‘stanford-ner-2018-10-16.zip.5’
#
# stanford-ner-2018-1 100%[===================>] 172.00M  5.13MB/s    in 31s
#
# 2024-07-31 11:49:24 (5.48 MB/s) - ‘stanford-ner-2018-10-16.zip.5’ saved [180358328/180358328]
#
# Archive:  stanford-ner-2018-10-16.zip
# replace stanford-ner-2018-10-16/README.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: stanford-ner-2018-10-16/README.txt
#   inflating: stanford-ner-2018-10-16/ner-gui.bat
#   inflating: stanford-ner-2018-10-16/build.xml
#   inflating: stanford-ner-2018-10-16/stanford-ner.jar
#   inflating: stanford-ner-2018-10-16/sample-conll-file.txt
#   inflating: stanford-ner-2018-10-16/sample.ner.txt
#   inflating: stanford-ner-2018-10-16/stanford-ner-3.9.2-sources.jar
#   inflating: stanford-ner-2018-10-16/lib/joda-time.jar
#   inflating: stanford-ner-2018-10-16/lib/stanford-ner-resources.jar
#   inflating: stanford-ner-2018-10-16/lib/jollyday-0.4.9.jar
#   inflating: stanford-ner-2018-10-16/ner-gui.command
#   inflating: stanford-ner-2018-10-16/ner.sh
#   inflating: stanford-ner-2018-10-16/stanford-ner-3.9.2.jar
#   inflating: stanford-ner-2018-10-16/NERDemo.java
#   inflating: stanford-ner-2018-10-16/stanford-ner-3.9.2-javadoc.jar
#   inflating: stanford-ner-2018-10-16/ner.bat
#   inflating: stanford-ner-2018-10-16/classifiers/english.conll.4class.distsim.prop
#   inflating: stanford-ner-2018-10-16/classifiers/example.serialized.ncc.ncc.ser.gz
#   inflating: stanford-ner-2018-10-16/classifiers/english.muc.7class.distsim.crf.ser.gz
#   inflating: stanford-ner-2018-10-16/classifiers/english.conll.4class.distsim.crf.ser.gz
#   inflating: stanford-ner-2018-10-16/classifiers/english.muc.7class.distsim.prop
#   inflating: stanford-ner-2018-10-16/classifiers/english.all.3class.distsim.prop
#   inflating: stanford-ner-2018-10-16/classifiers/example.serialized.ncc.prop
#   inflating: stanford-ner-2018-10-16/classifiers/english.all.3class.distsim.crf.ser.gz
#   inflating: stanford-ner-2018-10-16/sample.txt
#   inflating: stanford-ner-2018-10-16/sample-w-time.txt
#   inflating: stanford-ner-2018-10-16/ner-gui.sh
#   inflating: stanford-ner-2018-10-16/LICENSE.txt
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
# from transformers import pipeline
# emotion_classifier = pipeline("text-classification", model="j-hartmann/emotion-english-distilroberta-base", return_all_scores=False)

# sentence = 'While in France, Christine Lagarde discussed short-term stimulus efforts in a recent interview with the Wall Street Journal.'
# emotion = emotion_classifier(sentence)[0]
# print(emotion)
# new_emotion = emotion['label']
# Out:
# {'label': 'neutral', 'score': 0.8091278672218323}

# %%
# poem = """
# "Can someone make my simple wish come true?
# Male biker seeks female for touring fun.
# Do you live in North London? Is it you?
# Gay vegetarian whose friends are few,
# I'm into music, Shakespeare and the sun.
# Can someone make my simple wish come true?
# Executive in search of something new—
# Perhaps bisexual woman, arty, young.
# Do you live in North London? Is it you?
# Successful, straight and solvent? I am too—
# Attractive Jewish lady with a son.
# Can someone make my simple wish come true?
# I'm Libran, inexperienced and blue—
# Need slim, non-smoker, under twenty-one.
# Do you live in North London? Is it you?
# Please write (with photo) to Box 152.
# Who knows where it may lead once we've begun?
# Can someone make my simple wish come true?
# Do you live in North London? Is it you?"
# """

# segments = segment_poem_by_entities_and_emotion(poem)

# #printing the segments

# for i, segment in enumerate(segments):
#     emotion = emotion_classifier(segment)[0]
#     tokenized_segment = word_tokenize(segment)
#     tagged_segment = st.tag(tokenized_segment)

#     ner_tags = {(tag, word) for word, tag in tagged_segment if tag != 'O'}

#     print(f"Segment {i+1}:")
#     print(segment)
#     print(f"NER Tags: {ner_tags}")
#     print(f"Emotion: {emotion['label']} (Score: {emotion['score']:.2f})")
#     print()
# Out:
# Sentence:
# "Can someone make my simple wish come true?
# NER Tags: [("''", 'O'), ('Can', 'O'), ('someone', 'O'), ('make', 'O'), ('my', 'O'), ('simple', 'O'), ('wish', 'O'), ('come', 'O'), ('true', 'O'), ('?', 'O')]
# Emotion: neutral (Score: 0.52)
#
# Sentence: Male biker seeks female for touring fun.
# NER Tags: [('Male', 'O'), ('biker', 'O'), ('seeks', 'O'), ('female', 'O'), ('for', 'O'), ('touring', 'O'), ('fun', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.90)
#
# Sentence: Do you live in North London?
# NER Tags: [('Do', 'O'), ('you', 'O'), ('live', 'O'), ('in', 'O'), ('North', 'LOCATION'), ('London', 'LOCATION'), ('?', 'O')]
# Emotion: neutral (Score: 0.84)
#
# Sentence: Is it you?
# NER Tags: [('Is', 'O'), ('it', 'O'), ('you', 'O'), ('?', 'O')]
# Emotion: surprise (Score: 0.77)
#
# Sentence: Gay vegetarian whose friends are few,
# I'm into music, Shakespeare and the sun.
# NER Tags: [('Gay', 'O'), ('vegetarian', 'O'), ('whose', 'O'), ('friends', 'O'), ('are', 'O'), ('few', 'O'), (',', 'O'), ('I', 'O'), ("'m", 'O'), ('into', 'O'), ('music', 'O'), (',', 'O'), ('Shakespeare', 'PERSON'), ('and', 'O'), ('the', 'O'), ('sun', 'O'), ('.', 'O')]
# Emotion: joy (Score: 0.75)
#
# Sentence: Can someone make my simple wish come true?
# NER Tags: [('Can', 'O'), ('someone', 'O'), ('make', 'O'), ('my', 'O'), ('simple', 'O'), ('wish', 'O'), ('come', 'O'), ('true', 'O'), ('?', 'O')]
# Emotion: neutral (Score: 0.48)
#
# Sentence: Executive in search of something new—
# Perhaps bisexual woman, arty, young.
# NER Tags: [('Executive', 'O'), ('in', 'O'), ('search', 'O'), ('of', 'O'), ('something', 'O'), ('new—', 'O'), ('Perhaps', 'O'), ('bisexual', 'O'), ('woman', 'O'), (',', 'O'), ('arty', 'O'), (',', 'O'), ('young', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.50)
#
# Sentence: Do you live in North London?
# NER Tags: [('Do', 'O'), ('you', 'O'), ('live', 'O'), ('in', 'O'), ('North', 'LOCATION'), ('London', 'LOCATION'), ('?', 'O')]
# Emotion: neutral (Score: 0.84)
#
# Sentence: Is it you?
# NER Tags: [('Is', 'O'), ('it', 'O'), ('you', 'O'), ('?', 'O')]
# Emotion: surprise (Score: 0.77)
#
# Sentence: Successful, straight and solvent?
# NER Tags: [('Successful', 'O'), (',', 'O'), ('straight', 'O'), ('and', 'O'), ('solvent', 'O'), ('?', 'O')]
# Emotion: neutral (Score: 0.86)
#
# Sentence: I am too—
# Attractive Jewish lady with a son.
# NER Tags: [('I', 'O'), ('am', 'O'), ('too—', 'O'), ('Attractive', 'O'), ('Jewish', 'O'), ('lady', 'O'), ('with', 'O'), ('a', 'O'), ('son', 'O'), ('.', 'O')]
# Emotion: disgust (Score: 0.76)
#
# Sentence: Can someone make my simple wish come true?
# NER Tags: [('Can', 'O'), ('someone', 'O'), ('make', 'O'), ('my', 'O'), ('simple', 'O'), ('wish', 'O'), ('come', 'O'), ('true', 'O'), ('?', 'O')]
# Emotion: neutral (Score: 0.48)
#
# Sentence: I'm Libran, inexperienced and blue—
# Need slim, non-smoker, under twenty-one.
# NER Tags: [('I', 'O'), ("'m", 'O'), ('Libran', 'O'), (',', 'O'), ('inexperienced', 'O'), ('and', 'O'), ('blue—', 'O'), ('Need', 'O'), ('slim', 'O'), (',', 'O'), ('non-smoker', 'O'), (',', 'O'), ('under', 'O'), ('twenty-one', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.71)
#
# Sentence: Do you live in North London?
# NER Tags: [('Do', 'O'), ('you', 'O'), ('live', 'O'), ('in', 'O'), ('North', 'LOCATION'), ('London', 'LOCATION'), ('?', 'O')]
# Emotion: neutral (Score: 0.84)
#
# Sentence: Is it you?
# NER Tags: [('Is', 'O'), ('it', 'O'), ('you', 'O'), ('?', 'O')]
# Emotion: surprise (Score: 0.77)
#
# Sentence: Please write (with photo) to Box 152.
# Who knows where it may lead once we've begun?
# NER Tags: [('Please', 'O'), ('write', 'O'), ('(', 'O'), ('with', 'O'), ('photo', 'O'), (')', 'O'), ('to', 'O'), ('Box', 'O'), ('152.', 'O'), ('Who', 'O'), ('knows', 'O'), ('where', 'O'), ('it', 'O'), ('may', 'O'), ('lead', 'O'), ('once', 'O'), ('we', 'O'), ("'ve", 'O'), ('begun', 'O'), ('?', 'O')]
# Emotion: neutral (Score: 0.95)
#
# Sentence: Can someone make my simple wish come true?
# NER Tags: [('Can', 'O'), ('someone', 'O'), ('make', 'O'), ('my', 'O'), ('simple', 'O'), ('wish', 'O'), ('come', 'O'), ('true', 'O'), ('?', 'O')]
# Emotion: neutral (Score: 0.48)
#
# Sentence: Do you live in North London?
# NER Tags: [('Do', 'O'), ('you', 'O'), ('live', 'O'), ('in', 'O'), ('North', 'LOCATION'), ('London', 'LOCATION'), ('?', 'O')]
# Emotion: neutral (Score: 0.84)
#
# Sentence: Is it you?"
# NER Tags: [('Is', 'O'), ('it', 'O'), ('you', 'O'), ('?', 'O'), ("''", 'O')]
# Emotion: surprise (Score: 0.70)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-90fd8e6a9731> in <cell line: 27>()
#      27 for i, segment in enumerate(segments):
#      28     emotion = emotion_classifier(segment)[0]
# ---> 29     tokenized_segment = word_tokenize(segment)
#      30     tagged_segment = st.tag(tokenized_segment)
#      31
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/__init__.py in word_tokenize(text, language, preserve_line)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     105     """
#     106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
# --> 107     return tokenizer.tokenize(text)
#     108
#     109
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/punkt.py in tokenize(self, text, realign_boundaries)
#    1279         Given a text, returns a list of the sentences in that text.
#    1280         """
# -> 1281         return list(self.sentences_from_text(text, realign_boundaries))
#    1282
#    1283     def debug_decisions(self, text: str) -> Iterator[Dict[str, Any]]:
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/punkt.py in sentences_from_text(self, text, realign_boundaries)
#    1339         follows the period.
#    1340         """
# -> 1341         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1342
#    1343     def _get_last_whitespace_index(self, text: str) -> int:
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/punkt.py in <listcomp>(.0)
#    1339         follows the period.
#    1340         """
# -> 1341         return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#    1342
#    1343     def _get_last_whitespace_index(self, text: str) -> int:
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/punkt.py in span_tokenize(self, text, realign_boundaries)
#    1327         if realign_boundaries:
#    1328             slices = self._realign_boundaries(text, slices)
# -> 1329         for sentence in slices:
#    1330             yield (sentence.start, sentence.stop)
#    1331
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/punkt.py in _realign_boundaries(self, text, slices)
#    1457         """
#    1458         realign = 0
# -> 1459         for sentence1, sentence2 in _pair_iter(slices):
#    1460             sentence1 = slice(sentence1.start + realign, sentence1.stop)
#    1461             if not sentence2:
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/punkt.py in _pair_iter(iterator)
#     319     iterator = iter(iterator)
#     320     try:
# --> 321         prev = next(iterator)
#     322     except StopIteration:
#     323         return
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/punkt.py in _slices_from_text(self, text)
#    1429     def _slices_from_text(self, text: str) -> Iterator[slice]:
#    1430         last_break = 0
# -> 1431         for match, context in self._match_potential_end_contexts(text):
#    1432             if self.text_contains_sentbreak(context):
#    1433                 yield slice(last_break, match.end())
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/punkt.py in _match_potential_end_contexts(self, text)
#    1393         previous_slice = slice(0, 0)
#    1394         previous_match = None
# -> 1395         for match in self._lang_vars.period_context_re().finditer(text):
#    1396
#    1397             # Get the slice of the previous word
#
# TypeError: expected string or bytes-like object

# %%
import pandas as pd

# Create a new DataFrame with headers
df = pd.DataFrame(columns=['Title', 'Poet', 'text', 'ctext', 'Poem Link', 'our_summary', 'Segments', 'NER Tags', 'Emotions'])

# Save the DataFrame to a CSV file
df.to_csv('modified_poems.csv', index=False)

# %%
import csv
import pandas as pd
import os

def append_to_csv(file_path, data):
    with open(file_path, 'a', newline='') as f:
        writer = csv.writer(f)
        writer.writerow(data)

def get_existing_row_count(file_path):
    if not os.path.exists(file_path):
        return 0
    with open(file_path, 'r') as f:
        reader = csv.reader(f)
        row_count = sum(1 for row in reader)
    return row_count-1

df = pd.read_csv('/content/IITP_Poems - emnlp3000.csv')

existing_row_count = get_existing_row_count('/content/modified_poems (8).csv')

for index, row in df.iterrows():
    if index < existing_row_count:
        continue

    poem = row['ctext']
    segments, ner_tags, emotions = segment_poem_by_entities_and_emotion(poem)

    data_to_append = [
        row['Title'],
        row['Poet'],
        row['text'],
        row['ctext'],
        row['Poem Link'],
        row['our_summary'],
        segments,
        ner_tags,
        emotions
    ]

    append_to_csv('modified_poems.csv', data_to_append)
# Out:
# Sentence: I love you because the Earth turns round the sun because the North wind blows north sometimes because the Pope is Catholic and most Rabbis Jewish because the winters flow into springs and the air clears after a storm because only my love for you despite the charms of gravity keeps me from falling off this Earth into another dimension I love you because it is the natural order of things I love you like the habit I picked up in college of sleeping through lectures or saying I ’ m sorry when I get stopped for speeding because I drink a glass of water in the morning and chain-smoke cigarettes all through the day because I take my coffee Black and my milk with chocolate because you keep my feet warm though my life a mess I love you because I don ’ t want it any other way I am helpless in my love for you It makes me so happy to hear you call my name I am amazed you can resist locking me in an echo chamber where your voice reverberates through the four walls sending me into spasmatic ecstasy I love you because it ’ s been so good for so long that if I didn ’ t love you I ’ d have to be born again and that is not a theological statement I am pitiful in my love for you The Dells tell me Love is so simple the thought though of you sends indescribably delicious multitudinous thrills throughout and through-in my body I love you because no two snowflakes are alike and it is possible if you stand tippy-toe to walk between the raindrops I love you because I am afraid of the dark and can ’ t sleep in the light because I rub my eyes when I wake up in the morning and find you there because you with all your magic powers were determined that I should love you because there was nothing for you but that I would love you I love you because you made me want to love you more than I love my privacy my freedom my commitments and responsibilities I love you ’ cause I changed my life to love you because you saw me one Friday afternoon and decided that I would love you I love you I love you I love you
# NER Tags: [('I', 'O'), ('love', 'O'), ('you', 'O'), ('because', 'O'), ('the', 'O'), ('Earth', 'O'), ('turns', 'O'), ('round', 'O'), ('the', 'O'), ('sun', 'O'), ('because', 'O'), ('the', 'O'), ('North', 'O'), ('wind', 'O'), ('blows', 'O'), ('north', 'O'), ('sometimes', 'O'), ('because', 'O'), ('the', 'O'), ('Pope', 'O'), ('is', 'O'), ('Catholic', 'O'), ('and', 'O'), ('most', 'O'), ('Rabbis', 'O'), ('Jewish', 'O'), ('because', 'O'), ('the', 'O'), ('winters', 'O'), ('flow', 'O'), ('into', 'O'), ('springs', 'O'), ('and', 'O'), ('the', 'O'), ('air', 'O'), ('clears', 'O'), ('after', 'O'), ('a', 'O'), ('storm', 'O'), ('because', 'O'), ('only', 'O'), ('my', 'O'), ('love', 'O'), ('for', 'O'), ('you', 'O'), ('despite', 'O'), ('the', 'O'), ('charms', 'O'), ('of', 'O'), ('gravity', 'O'), ('keeps', 'O'), ('me', 'O'), ('from', 'O'), ('falling', 'O'), ('off', 'O'), ('this', 'O'), ('Earth', 'LOCATION'), ('into', 'O'), ('another', 'O'), ('dimension', 'O'), ('I', 'O'), ('love', 'O'), ('you', 'O'), ('because', 'O'), ('it', 'O'), ('is', 'O'), ('the', 'O'), ('natural', 'O'), ('order', 'O'), ('of', 'O'), ('things', 'O'), ('I', 'O'), ('love', 'O'), ('you', 'O'), ('like', 'O'), ('the', 'O'), ('habit', 'O'), ('I', 'O'), ('picked', 'O'), ('up', 'O'), ('in', 'O'), ('college', 'O'), ('of', 'O'), ('sleeping', 'O'), ('through', 'O'), ('lectures', 'O'), ('or', 'O'), ('saying', 'O'), ('I', 'O'), ('’', 'O'), ('m', 'O'), ('sorry', 'O'), ('when', 'O'), ('I', 'O'), ('get', 'O'), ('stopped', 'O'), ('for', 'O'), ('speeding', 'O'), ('because', 'O'), ('I', 'O'), ('drink', 'O'), ('a', 'O'), ('glass', 'O'), ('of', 'O'), ('water', 'O'), ('in', 'O'), ('the', 'O'), ('morning', 'O'), ('and', 'O'), ('chain-smoke', 'O'), ('cigarettes', 'O'), ('all', 'O'), ('through', 'O'), ('the', 'O'), ('day', 'O'), ('because', 'O'), ('I', 'O'), ('take', 'O'), ('my', 'O'), ('coffee', 'O'), ('Black', 'O'), ('and', 'O'), ('my', 'O'), ('milk', 'O'), ('with', 'O'), ('chocolate', 'O'), ('because', 'O'), ('you', 'O'), ('keep', 'O'), ('my', 'O'), ('feet', 'O'), ('warm', 'O'), ('though', 'O'), ('my', 'O'), ('life', 'O'), ('a', 'O'), ('mess', 'O'), ('I', 'O'), ('love', 'O'), ('you', 'O'), ('because', 'O'), ('I', 'O'), ('don', 'O'), ('’', 'O'), ('t', 'O'), ('want', 'O'), ('it', 'O'), ('any', 'O'), ('other', 'O'), ('way', 'O'), ('I', 'O'), ('am', 'O'), ('helpless', 'O'), ('in', 'O'), ('my', 'O'), ('love', 'O'), ('for', 'O'), ('you', 'O'), ('It', 'O'), ('makes', 'O'), ('me', 'O'), ('so', 'O'), ('happy', 'O'), ('to', 'O'), ('hear', 'O'), ('you', 'O'), ('call', 'O'), ('my', 'O'), ('name', 'O'), ('I', 'O'), ('am', 'O'), ('amazed', 'O'), ('you', 'O'), ('can', 'O'), ('resist', 'O'), ('locking', 'O'), ('me', 'O'), ('in', 'O'), ('an', 'O'), ('echo', 'O'), ('chamber', 'O'), ('where', 'O'), ('your', 'O'), ('voice', 'O'), ('reverberates', 'O'), ('through', 'O'), ('the', 'O'), ('four', 'O'), ('walls', 'O'), ('sending', 'O'), ('me', 'O'), ('into', 'O'), ('spasmatic', 'O'), ('ecstasy', 'O'), ('I', 'O'), ('love', 'O'), ('you', 'O'), ('because', 'O'), ('it', 'O'), ('’', 'O'), ('s', 'O'), ('been', 'O'), ('so', 'O'), ('good', 'O'), ('for', 'O'), ('so', 'O'), ('long', 'O'), ('that', 'O'), ('if', 'O'), ('I', 'O'), ('didn', 'O'), ('’', 'O'), ('t', 'O'), ('love', 'O'), ('you', 'O'), ('I', 'O'), ('’', 'O'), ('d', 'O'), ('have', 'O'), ('to', 'O'), ('be', 'O'), ('born', 'O'), ('again', 'O'), ('and', 'O'), ('that', 'O'), ('is', 'O'), ('not', 'O'), ('a', 'O'), ('theological', 'O'), ('statement', 'O'), ('I', 'O'), ('am', 'O'), ('pitiful', 'O'), ('in', 'O'), ('my', 'O'), ('love', 'O'), ('for', 'O'), ('you', 'O'), ('The', 'O'), ('Dells', 'ORGANIZATION'), ('tell', 'O'), ('me', 'O'), ('Love', 'O'), ('is', 'O'), ('so', 'O'), ('simple', 'O'), ('the', 'O'), ('thought', 'O'), ('though', 'O'), ('of', 'O'), ('you', 'O'), ('sends', 'O'), ('indescribably', 'O'), ('delicious', 'O'), ('multitudinous', 'O'), ('thrills', 'O'), ('throughout', 'O'), ('and', 'O'), ('through-in', 'O'), ('my', 'O'), ('body', 'O'), ('I', 'O'), ('love', 'O'), ('you', ...
# Emotion: sadness (Score: 0.60)
#
# ['I love you because the Earth turns round the sun because the North wind blows north sometimes because the Pope is Catholic and most Rabbis Jewish because the winters flow into springs and the air clears after a storm because only my love for you despite the charms of gravity keeps me from falling off this Earth into another dimension I love you because it is the natural order of things I love you like the habit I picked up in college of sleeping through lectures or saying I ’ m sorry when I get stopped for speeding because I drink a glass of water in the morning and chain-smoke cigarettes all through the day because I take my coffee Black and my milk with chocolate because you keep my feet warm though my life a mess I love you because I don ’ t want it any other way I am helpless in my love for you It makes me so happy to hear you call my name I am amazed you can resist locking me in an echo chamber where your voice reverberates through the four walls sending me into spasmatic ecstasy I love you because it ’ s been so good for so long that if I didn ’ t love you I ’ d have to be born again and that is not a theological statement I am pitiful in my love for you The Dells tell me Love is so simple the thought though of you sends indescribably delicious multitudinous thrills throughout and through-in my body I love you because no two snowflakes are alike and it is possible if you stand tippy-toe to walk between the raindrops I love you because I am afraid of the dark and can ’ t sleep in the light because I rub my eyes when I wake up in the morning and find you there because you with all your magic powers were determined that I should love you because there was nothing for you but that I would love you I love you because you made me want to love you more than I love my privacy my freedom my commitments and responsibilities I love you ’ cause I changed my life to love you because you saw me one Friday afternoon and decided that I would love you I love you I love you I love you']
#
# [{'PERSON': set(), 'ORGANIZATION': {'Dells'}, 'LOCATION': {'Earth'}}]
#
# ['sadness']
# Sentence: In the cold , cold parlor my mother laid out Arthur beneath the chromographs : Edward , Prince of Wales , with Princess Alexandra , and King George with Queen Mary .
# NER Tags: [('In', 'O'), ('the', 'O'), ('cold', 'O'), (',', 'O'), ('cold', 'O'), ('parlor', 'O'), ('my', 'O'), ('mother', 'O'), ('laid', 'O'), ('out', 'O'), ('Arthur', 'PERSON'), ('beneath', 'O'), ('the', 'O'), ('chromographs', 'O'), (':', 'O'), ('Edward', 'PERSON'), (',', 'O'), ('Prince', 'O'), ('of', 'O'), ('Wales', 'LOCATION'), (',', 'O'), ('with', 'O'), ('Princess', 'O'), ('Alexandra', 'PERSON'), (',', 'O'), ('and', 'O'), ('King', 'O'), ('George', 'PERSON'), ('with', 'O'), ('Queen', 'PERSON'), ('Mary', 'PERSON'), ('.', 'O')]
# Emotion: anger (Score: 0.79)
#
# Sentence: Below them on the table stood a stuffed loon shot and stuffed by Uncle Arthur , Arthur 's father .
# NER Tags: [('Below', 'O'), ('them', 'O'), ('on', 'O'), ('the', 'O'), ('table', 'O'), ('stood', 'O'), ('a', 'O'), ('stuffed', 'O'), ('loon', 'O'), ('shot', 'O'), ('and', 'O'), ('stuffed', 'O'), ('by', 'O'), ('Uncle', 'PERSON'), ('Arthur', 'PERSON'), (',', 'O'), ('Arthur', 'PERSON'), ("'s", 'O'), ('father', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.62)
#
# Sentence: Since Uncle Arthur fired a bullet into him , he had n't said a word .
# NER Tags: [('Since', 'O'), ('Uncle', 'PERSON'), ('Arthur', 'PERSON'), ('fired', 'O'), ('a', 'O'), ('bullet', 'O'), ('into', 'O'), ('him', 'O'), (',', 'O'), ('he', 'O'), ('had', 'O'), ("n't", 'O'), ('said', 'O'), ('a', 'O'), ('word', 'O'), ('.', 'O')]
# Emotion: anger (Score: 0.37)
#
# Sentence: He kept his own counsel on his white , frozen lake , the marble-topped table .
# NER Tags: [('He', 'O'), ('kept', 'O'), ('his', 'O'), ('own', 'O'), ('counsel', 'O'), ('on', 'O'), ('his', 'O'), ('white', 'O'), (',', 'O'), ('frozen', 'O'), ('lake', 'O'), (',', 'O'), ('the', 'O'), ('marble-topped', 'O'), ('table', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.77)
#
# Sentence: His breast was deep and white , cold and caressable ; his eyes were red glass , much to be desired .
# NER Tags: [('His', 'O'), ('breast', 'O'), ('was', 'O'), ('deep', 'O'), ('and', 'O'), ('white', 'O'), (',', 'O'), ('cold', 'O'), ('and', 'O'), ('caressable', 'O'), (';', 'O'), ('his', 'O'), ('eyes', 'O'), ('were', 'O'), ('red', 'O'), ('glass', 'O'), (',', 'O'), ('much', 'O'), ('to', 'O'), ('be', 'O'), ('desired', 'O'), ('.', 'O')]
# Emotion: anger (Score: 0.59)
#
# Sentence: `` Come , '' said my mother , '' Come and say good-bye to your little cousin Arthur . ''
# NER Tags: [('``', 'O'), ('Come', 'O'), (',', 'O'), ('``', 'O'), ('said', 'O'), ('my', 'O'), ('mother', 'O'), (',', 'O'), ('``', 'O'), ('Come', 'O'), ('and', 'O'), ('say', 'O'), ('good-bye', 'O'), ('to', 'O'), ('your', 'O'), ('little', 'O'), ('cousin', 'O'), ('Arthur', 'PERSON'), ('.', 'O'), ('``', 'O')]
# Emotion: neutral (Score: 0.60)
#
# Sentence: I was lifted up and given one lily of the valley to put in Arthur 's hand .
# NER Tags: [('I', 'O'), ('was', 'O'), ('lifted', 'O'), ('up', 'O'), ('and', 'O'), ('given', 'O'), ('one', 'O'), ('lily', 'O'), ('of', 'O'), ('the', 'O'), ('valley', 'O'), ('to', 'O'), ('put', 'O'), ('in', 'O'), ('Arthur', 'PERSON'), ("'s", 'O'), ('hand', 'O'), ('.', 'O')]
# Emotion: joy (Score: 0.53)
#
# Sentence: Arthur 's coffin was a little frosted cake , and the red-eyed loon eyed it from his white , frozen lake .
# NER Tags: [('Arthur', 'PERSON'), ("'s", 'O'), ('coffin', 'O'), ('was', 'O'), ('a', 'O'), ('little', 'O'), ('frosted', 'O'), ('cake', 'O'), (',', 'O'), ('and', 'O'), ('the', 'O'), ('red-eyed', 'O'), ('loon', 'O'), ('eyed', 'O'), ('it', 'O'), ('from', 'O'), ('his', 'O'), ('white', 'O'), (',', 'O'), ('frozen', 'O'), ('lake', 'O'), ('.', 'O')]
# Emotion: sadness (Score: 0.39)
#
# Sentence: Arthur was very small .
# NER Tags: [('Arthur', 'PERSON'), ('was', 'O'), ('very', 'O'), ('small', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.62)
#
# Sentence: He was all white , like a doll that had n't been painted yet .
# NER Tags: [('He', 'O'), ('was', 'O'), ('all', 'O'), ('white', 'O'), (',', 'O'), ('like', 'O'), ('a', 'O'), ('doll', 'O'), ('that', 'O'), ('had', 'O'), ("n't", 'O'), ('been', 'O'), ('painted', 'O'), ('yet', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.86)
#
# Sentence: Jack Frost had started to paint him the way he always painted the Maple Leaf ( Forever ) .
# NER Tags: [('Jack', 'PERSON'), ('Frost', 'PERSON'), ('had', 'O'), ('started', 'O'), ('to', 'O'), ('paint', 'O'), ('him', 'O'), ('the', 'O'), ('way', 'O'), ('he', 'O'), ('always', 'O'), ('painted', 'O'), ('the', 'O'), ('Maple', 'O'), ('Leaf', 'O'), ('(', 'O'), ('Forever', 'O'), (')', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.85)
#
# Sentence: He had just begun on his hair , a few red strokes , and then Jack Frost had dropped the brush and left him white , forever .
# NER Tags: [('He', 'O'), ('had', 'O'), ('just', 'O'), ('begun', 'O'), ('on', 'O'), ('his', 'O'), ('hair', 'O'), (',', 'O'), ('a', 'O'), ('few', 'O'), ('red', 'O'), ('strokes', 'O'), (',', 'O'), ('and', 'O'), ('then', 'O'), ('Jack', 'PERSON'), ('Frost', 'PERSON'), ('had', 'O'), ('dropped', 'O'), ('the', 'O'), ('brush', 'O'), ('and', 'O'), ('left', 'O'), ('him', 'O'), ('white', 'O'), (',', 'O'), ('forever', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.79)
#
# Sentence: The gracious royal couples were warm in red and ermine ; their feet were well wrapped up in the ladies ' ermine trains .
# NER Tags: [('The', 'O'), ('gracious', 'O'), ('royal', 'O'), ('couples', 'O'), ('were', 'O'), ('warm', 'O'), ('in', 'O'), ('red', 'O'), ('and', 'O'), ('ermine', 'O'), (';', 'O'), ('their', 'O'), ('feet', 'O'), ('were', 'O'), ('well', 'O'), ('wrapped', 'O'), ('up', 'O'), ('in', 'O'), ('the', 'O'), ('ladies', 'O'), ("'", 'O'), ('ermine', 'O'), ('trains', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.55)
#
# Sentence: They invited Arthur to be the smallest page at court .
# NER Tags: [('They', 'O'), ('invited', 'O'), ('Arthur', 'PERSON'), ('to', 'O'), ('be', 'O'), ('the', 'O'), ('smallest', 'O'), ('page', 'O'), ('at', 'O'), ('court', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.66)
#
# Sentence: But how could Arthur go , clutching his tiny lily , with his eyes shut up so tight and the roads deep in snow ?
# NER Tags: [('But', 'O'), ('how', 'O'), ('could', 'O'), ('Arthur', 'PERSON'), ('go', 'O'), (',', 'O'), ('clutching', 'O'), ('his', 'O'), ('tiny', 'O'), ('lily', 'O'), (',', 'O'), ('with', 'O'), ('his', 'O'), ('eyes', 'O'), ('shut', 'O'), ('up', 'O'), ('so', 'O'), ('tight', 'O'), ('and', 'O'), ('the', 'O'), ('roads', 'O'), ('deep', 'O'), ('in', 'O'), ('snow', 'O'), ('?', 'O')]
# Emotion: surprise (Score: 0.56)
#
# ['In the cold , cold parlor my mother laid out Arthur beneath the chromographs : Edward , Prince of Wales , with Princess Alexandra , and King George with Queen Mary .', "Below them on the table stood a stuffed loon shot and stuffed by Uncle Arthur , Arthur 's father .", "Since Uncle Arthur fired a bullet into him , he had n't said a word .", 'He kept his own counsel on his white , frozen lake , the marble-topped table .', 'His breast was deep and white , cold and caressable ; his eyes were red glass , much to be desired .', "`` Come , '' said my mother , '' Come and say good-bye to your little cousin Arthur . ''", "I was lifted up and given one lily of the valley to put in Arthur 's hand .", "Arthur 's coffin was a little frosted cake , and the red-eyed loon eyed it from his white , frozen lake .", "Arthur was very small . He was all white , like a doll that had n't been painted yet .", "Jack Frost had started to paint him the way he always painted the Maple Leaf ( Forever ) . He had just begun on his hair , a few red strokes , and then Jack Frost had dropped the brush and left him white , forever . The gracious royal couples were warm in red and ermine ; their feet were well wrapped up in the ladies ' ermine trains .", 'They invited Arthur to be the smallest page at court .', 'But how could Arthur go , clutching his tiny lily , with his eyes shut up so tight and the roads deep in snow ?']
#
# [{'PERSON': {'Queen', 'Mary', 'Alexandra', 'George', 'Edward', 'Arthur'}, 'ORGANIZATION': set(), 'LOCATION': {'Wales'}}, {'PERSON': {'Uncle', 'Arthur'}, 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': {'Uncle', 'Arthur'}, 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': {'Arthur'}, 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': {'Arthur'}, 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': {'Arthur'}, 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': {'Arthur'}, 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': {'Jack', 'Frost'}, 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': {'Arthur'}, 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': {'Arthur'}, 'ORGANIZATION': set(), 'LOCATION': set()}]
#
# ['anger', 'neutral', 'anger', 'neutral', 'anger', 'neutral', 'joy', 'sadness', 'neutral', 'neutral', 'neutral', 'surprise']
# Sentence: Little Lamb who made thee Dost thou know who made thee Gave thee life & bid thee feed .
# NER Tags: [('Little', 'O'), ('Lamb', 'O'), ('who', 'O'), ('made', 'O'), ('thee', 'O'), ('Dost', 'PERSON'), ('thou', 'O'), ('know', 'O'), ('who', 'O'), ('made', 'O'), ('thee', 'O'), ('Gave', 'O'), ('thee', 'O'), ('life', 'O'), ('&', 'O'), ('bid', 'O'), ('thee', 'O'), ('feed', 'O'), ('.', 'O')]
# Emotion: anger (Score: 0.31)
#
# Sentence: By the stream & o'er the mead ; Gave thee clothing of delight , Softest clothing wooly bright ; Gave thee such a tender voice , Making all the vales rejoice !
# NER Tags: [('By', 'O'), ('the', 'O'), ('stream', 'O'), ('&', 'O'), ("o'er", 'O'), ('the', 'O'), ('mead', 'O'), (';', 'O'), ('Gave', 'O'), ('thee', 'O'), ('clothing', 'O'), ('of', 'O'), ('delight', 'O'), (',', 'O'), ('Softest', 'O'), ('clothing', 'O'), ('wooly', 'O'), ('bright', 'O'), (';', 'O'), ('Gave', 'O'), ('thee', 'O'), ('such', 'O'), ('a', 'O'), ('tender', 'O'), ('voice', 'O'), (',', 'O'), ('Making', 'O'), ('all', 'O'), ('the', 'O'), ('vales', 'O'), ('rejoice', 'O'), ('!', 'O')]
# Emotion: joy (Score: 0.99)
#
# Sentence: Little Lamb who made thee Dost thou know who made thee Little Lamb I 'll tell thee , Little Lamb I 'll tell thee !
# NER Tags: [('Little', 'O'), ('Lamb', 'O'), ('who', 'O'), ('made', 'O'), ('thee', 'O'), ('Dost', 'PERSON'), ('thou', 'O'), ('know', 'O'), ('who', 'O'), ('made', 'O'), ('thee', 'O'), ('Little', 'O'), ('Lamb', 'O'), ('I', 'O'), ("'ll", 'O'), ('tell', 'O'), ('thee', 'O'), (',', 'O'), ('Little', 'O'), ('Lamb', 'O'), ('I', 'O'), ("'ll", 'O'), ('tell', 'O'), ('thee', 'O'), ('!', 'O')]
# Emotion: neutral (Score: 0.35)
#
# Sentence: He is called by thy name , For he calls himself a Lamb : He is meek & he is mild , He became a little child : I a child & thou a lamb , We are called by his name .
# NER Tags: [('He', 'O'), ('is', 'O'), ('called', 'O'), ('by', 'O'), ('thy', 'O'), ('name', 'O'), (',', 'O'), ('For', 'O'), ('he', 'O'), ('calls', 'O'), ('himself', 'O'), ('a', 'O'), ('Lamb', 'O'), (':', 'O'), ('He', 'O'), ('is', 'O'), ('meek', 'O'), ('&', 'O'), ('he', 'O'), ('is', 'O'), ('mild', 'O'), (',', 'O'), ('He', 'O'), ('became', 'O'), ('a', 'O'), ('little', 'O'), ('child', 'O'), (':', 'O'), ('I', 'O'), ('a', 'O'), ('child', 'O'), ('&', 'O'), ('thou', 'O'), ('a', 'O'), ('lamb', 'O'), (',', 'O'), ('We', 'O'), ('are', 'O'), ('called', 'O'), ('by', 'O'), ('his', 'O'), ('name', 'O'), ('.', 'O')]
# Emotion: disgust (Score: 0.90)
#
# Sentence: Little Lamb God bless thee .
# NER Tags: [('Little', 'O'), ('Lamb', 'O'), ('God', 'O'), ('bless', 'O'), ('thee', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.49)
#
# Sentence: Little Lamb God bless thee .
# NER Tags: [('Little', 'O'), ('Lamb', 'O'), ('God', 'O'), ('bless', 'O'), ('thee', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.49)
#
# ['Little Lamb who made thee Dost thou know who made thee Gave thee life & bid thee feed .', "By the stream & o'er the mead ; Gave thee clothing of delight , Softest clothing wooly bright ; Gave thee such a tender voice , Making all the vales rejoice !", "Little Lamb who made thee Dost thou know who made thee Little Lamb I 'll tell thee , Little Lamb I 'll tell thee !", 'He is called by thy name , For he calls himself a Lamb : He is meek & he is mild , He became a little child : I a child & thou a lamb , We are called by his name .', 'Little Lamb God bless thee . Little Lamb God bless thee .']
#
# [{'PERSON': {'Dost'}, 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': {'Dost'}, 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}]
#
# ['anger', 'joy', 'neutral', 'disgust', 'neutral']
# Sentence: He climbed toward the blinding light and when his eyes adjusted he looked down and could see his fellow prisoners captivated by shadows ; everything he had believed was false .
# NER Tags: [('He', 'O'), ('climbed', 'O'), ('toward', 'O'), ('the', 'O'), ('blinding', 'O'), ('light', 'O'), ('and', 'O'), ('when', 'O'), ('his', 'O'), ('eyes', 'O'), ('adjusted', 'O'), ('he', 'O'), ('looked', 'O'), ('down', 'O'), ('and', 'O'), ('could', 'O'), ('see', 'O'), ('his', 'O'), ('fellow', 'O'), ('prisoners', 'O'), ('captivated', 'O'), ('by', 'O'), ('shadows', 'O'), (';', 'O'), ('everything', 'O'), ('he', 'O'), ('had', 'O'), ('believed', 'O'), ('was', 'O'), ('false', 'O'), ('.', 'O')]
# Emotion: fear (Score: 0.75)
#
# Sentence: And he was suddenly in the 20th century , in the sunlight and violence of history , encumbered by knowledge .
# NER Tags: [('And', 'O'), ('he', 'O'), ('was', 'O'), ('suddenly', 'O'), ('in', 'O'), ('the', 'O'), ('20th', 'O'), ('century', 'O'), (',', 'O'), ('in', 'O'), ('the', 'O'), ('sunlight', 'O'), ('and', 'O'), ('violence', 'O'), ('of', 'O'), ('history', 'O'), (',', 'O'), ('encumbered', 'O'), ('by', 'O'), ('knowledge', 'O'), ('.', 'O')]
# Emotion: surprise (Score: 0.85)
#
# Sentence: Only a hero would dare return with the truth .
# NER Tags: [('Only', 'O'), ('a', 'O'), ('hero', 'O'), ('would', 'O'), ('dare', 'O'), ('return', 'O'), ('with', 'O'), ('the', 'O'), ('truth', 'O'), ('.', 'O')]
# Emotion: anger (Score: 0.91)
#
# Sentence: So from the cave 's upper reaches , removed from harm , he called out the disturbing news .
# NER Tags: [('So', 'O'), ('from', 'O'), ('the', 'O'), ('cave', 'O'), ("'s", 'O'), ('upper', 'O'), ('reaches', 'O'), (',', 'O'), ('removed', 'O'), ('from', 'O'), ('harm', 'O'), (',', 'O'), ('he', 'O'), ('called', 'O'), ('out', 'O'), ('the', 'O'), ('disturbing', 'O'), ('news', 'O'), ('.', 'O')]
# Emotion: fear (Score: 0.69)
#
# Sentence: What lovely echoes , the prisoners said , what a fine musical place to live .
# NER Tags: [('What', 'O'), ('lovely', 'O'), ('echoes', 'O'), (',', 'O'), ('the', 'O'), ('prisoners', 'O'), ('said', 'O'), (',', 'O'), ('what', 'O'), ('a', 'O'), ('fine', 'O'), ('musical', 'O'), ('place', 'O'), ('to', 'O'), ('live', 'O'), ('.', 'O')]
# Emotion: joy (Score: 0.98)
#
# Sentence: He spelled it out , then , in clear prose on paper scraps , which he floated down .
# NER Tags: [('He', 'O'), ('spelled', 'O'), ('it', 'O'), ('out', 'O'), (',', 'O'), ('then', 'O'), (',', 'O'), ('in', 'O'), ('clear', 'O'), ('prose', 'O'), ('on', 'O'), ('paper', 'O'), ('scraps', 'O'), (',', 'O'), ('which', 'O'), ('he', 'O'), ('floated', 'O'), ('down', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.95)
#
# Sentence: But in the semi-dark they read his words with the indulgence of those who seldom read : It 's about my father 's death , one of them said .
# NER Tags: [('But', 'O'), ('in', 'O'), ('the', 'O'), ('semi-dark', 'O'), ('they', 'O'), ('read', 'O'), ('his', 'O'), ('words', 'O'), ('with', 'O'), ('the', 'O'), ('indulgence', 'O'), ('of', 'O'), ('those', 'O'), ('who', 'O'), ('seldom', 'O'), ('read', 'O'), (':', 'O'), ('It', 'O'), ("'s", 'O'), ('about', 'O'), ('my', 'O'), ('father', 'O'), ("'s", 'O'), ('death', 'O'), (',', 'O'), ('one', 'O'), ('of', 'O'), ('them', 'O'), ('said', 'O'), ('.', 'O')]
# Emotion: sadness (Score: 0.75)
#
# Sentence: No , said the others , it 's a joke .
# NER Tags: [('No', 'O'), (',', 'O'), ('said', 'O'), ('the', 'O'), ('others', 'O'), (',', 'O'), ('it', 'O'), ("'s", 'O'), ('a', 'O'), ('joke', 'O'), ('.', 'O')]
# Emotion: joy (Score: 0.53)
#
# Sentence: By this time he no longer was sure of what he 'd seen .
# NER Tags: [('By', 'O'), ('this', 'O'), ('time', 'O'), ('he', 'O'), ('no', 'O'), ('longer', 'O'), ('was', 'O'), ('sure', 'O'), ('of', 'O'), ('what', 'O'), ('he', 'O'), ("'d", 'O'), ('seen', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.65)
#
# Sentence: Was n't sunlight a shadow too ?
# NER Tags: [('Was', 'O'), ("n't", 'O'), ('sunlight', 'O'), ('a', 'O'), ('shadow', 'O'), ('too', 'O'), ('?', 'O')]
# Emotion: neutral (Score: 0.70)
#
# Sentence: Was n't there always a source behind a source ?
# NER Tags: [('Was', 'O'), ("n't", 'O'), ('there', 'O'), ('always', 'O'), ('a', 'O'), ('source', 'O'), ('behind', 'O'), ('a', 'O'), ('source', 'O'), ('?', 'O')]
# Emotion: neutral (Score: 0.87)
#
# Sentence: He just stood there , confused , a man who had moved to larger errors , without a prayer .
# NER Tags: [('He', 'O'), ('just', 'O'), ('stood', 'O'), ('there', 'O'), (',', 'O'), ('confused', 'O'), (',', 'O'), ('a', 'O'), ('man', 'O'), ('who', 'O'), ('had', 'O'), ('moved', 'O'), ('to', 'O'), ('larger', 'O'), ('errors', 'O'), (',', 'O'), ('without', 'O'), ('a', 'O'), ('prayer', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.66)
#
# ['He climbed toward the blinding light and when his eyes adjusted he looked down and could see his fellow prisoners captivated by shadows ; everything he had believed was false .', 'And he was suddenly in the 20th century , in the sunlight and violence of history , encumbered by knowledge .', 'Only a hero would dare return with the truth .', "So from the cave 's upper reaches , removed from harm , he called out the disturbing news .", 'What lovely echoes , the prisoners said , what a fine musical place to live .', 'He spelled it out , then , in clear prose on paper scraps , which he floated down .', "But in the semi-dark they read his words with the indulgence of those who seldom read : It 's about my father 's death , one of them said .", "No , said the others , it 's a joke .", "By this time he no longer was sure of what he 'd seen . Was n't sunlight a shadow too ? Was n't there always a source behind a source ? He just stood there , confused , a man who had moved to larger errors , without a prayer ."]
#
# [{'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}]
#
# ['fear', 'surprise', 'anger', 'fear', 'joy', 'neutral', 'sadness', 'joy', 'neutral']
# Sentence: And God stepped out on space , And he looked around and said : I 'm lonely— I 'll make me a world .
# NER Tags: [('And', 'O'), ('God', 'O'), ('stepped', 'O'), ('out', 'O'), ('on', 'O'), ('space', 'O'), (',', 'O'), ('And', 'O'), ('he', 'O'), ('looked', 'O'), ('around', 'O'), ('and', 'O'), ('said', 'O'), (':', 'O'), ('I', 'O'), ("'m", 'O'), ('lonely—', 'O'), ('I', 'O'), ("'ll", 'O'), ('make', 'O'), ('me', 'O'), ('a', 'O'), ('world', 'O'), ('.', 'O')]
# Emotion: sadness (Score: 0.69)
#
# Sentence: And far as the eye of God could see Darkness covered everything , Blacker than a hundred midnights Down in a cypress swamp .
# NER Tags: [('And', 'O'), ('far', 'O'), ('as', 'O'), ('the', 'O'), ('eye', 'O'), ('of', 'O'), ('God', 'O'), ('could', 'O'), ('see', 'O'), ('Darkness', 'O'), ('covered', 'O'), ('everything', 'O'), (',', 'O'), ('Blacker', 'PERSON'), ('than', 'O'), ('a', 'O'), ('hundred', 'O'), ('midnights', 'O'), ('Down', 'O'), ('in', 'O'), ('a', 'O'), ('cypress', 'O'), ('swamp', 'O'), ('.', 'O')]
# Emotion: fear (Score: 0.43)
#
# Sentence: Then God smiled , And the light broke , And the darkness rolled up on one side , And the light stood shining on the other , And God said : That 's good !
# NER Tags: [('Then', 'O'), ('God', 'O'), ('smiled', 'O'), (',', 'O'), ('And', 'O'), ('the', 'O'), ('light', 'O'), ('broke', 'O'), (',', 'O'), ('And', 'O'), ('the', 'O'), ('darkness', 'O'), ('rolled', 'O'), ('up', 'O'), ('on', 'O'), ('one', 'O'), ('side', 'O'), (',', 'O'), ('And', 'O'), ('the', 'O'), ('light', 'O'), ('stood', 'O'), ('shining', 'O'), ('on', 'O'), ('the', 'O'), ('other', 'O'), (',', 'O'), ('And', 'O'), ('God', 'O'), ('said', 'O'), (':', 'O'), ('That', 'O'), ("'s", 'O'), ('good', 'O'), ('!', 'O')]
# Emotion: joy (Score: 0.88)
#
# Sentence: Then God reached out and took the light in his hands , And God rolled the light around in his hands Until he made the sun ; And he set that sun a-blazing in the heavens .
# NER Tags: [('Then', 'O'), ('God', 'O'), ('reached', 'O'), ('out', 'O'), ('and', 'O'), ('took', 'O'), ('the', 'O'), ('light', 'O'), ('in', 'O'), ('his', 'O'), ('hands', 'O'), (',', 'O'), ('And', 'O'), ('God', 'O'), ('rolled', 'O'), ('the', 'O'), ('light', 'O'), ('around', 'O'), ('in', 'O'), ('his', 'O'), ('hands', 'O'), ('Until', 'O'), ('he', 'O'), ('made', 'O'), ('the', 'O'), ('sun', 'O'), (';', 'O'), ('And', 'O'), ('he', 'O'), ('set', 'O'), ('that', 'O'), ('sun', 'O'), ('a-blazing', 'O'), ('in', 'O'), ('the', 'O'), ('heavens', 'O'), ('.', 'O')]
# Emotion: anger (Score: 0.28)
#
# Sentence: And the light that was left from making the sun God gathered it up in a shining ball And flung it against the darkness , Spangling the night with the moon and stars .
# NER Tags: [('And', 'O'), ('the', 'O'), ('light', 'O'), ('that', 'O'), ('was', 'O'), ('left', 'O'), ('from', 'O'), ('making', 'O'), ('the', 'O'), ('sun', 'O'), ('God', 'O'), ('gathered', 'O'), ('it', 'O'), ('up', 'O'), ('in', 'O'), ('a', 'O'), ('shining', 'O'), ('ball', 'O'), ('And', 'O'), ('flung', 'O'), ('it', 'O'), ('against', 'O'), ('the', 'O'), ('darkness', 'O'), (',', 'O'), ('Spangling', 'O'), ('the', 'O'), ('night', 'O'), ('with', 'O'), ('the', 'O'), ('moon', 'O'), ('and', 'O'), ('stars', 'O'), ('.', 'O')]
# Emotion: sadness (Score: 0.41)
#
# Sentence: Then down between The darkness and the light He hurled the world ; And God said : That 's good !
# NER Tags: [('Then', 'O'), ('down', 'O'), ('between', 'O'), ('The', 'O'), ('darkness', 'O'), ('and', 'O'), ('the', 'O'), ('light', 'O'), ('He', 'O'), ('hurled', 'O'), ('the', 'O'), ('world', 'O'), (';', 'O'), ('And', 'O'), ('God', 'O'), ('said', 'O'), (':', 'O'), ('That', 'O'), ("'s", 'O'), ('good', 'O'), ('!', 'O')]
# Emotion: joy (Score: 0.49)
#
# Sentence: Then God himself stepped down— And the sun was on his right hand , And the moon was on his left ; The stars were clustered about his head , And the earth was under his feet .
# NER Tags: [('Then', 'O'), ('God', 'O'), ('himself', 'O'), ('stepped', 'O'), ('down—', 'O'), ('And', 'O'), ('the', 'O'), ('sun', 'O'), ('was', 'O'), ('on', 'O'), ('his', 'O'), ('right', 'O'), ('hand', 'O'), (',', 'O'), ('And', 'O'), ('the', 'O'), ('moon', 'O'), ('was', 'O'), ('on', 'O'), ('his', 'O'), ('left', 'O'), (';', 'O'), ('The', 'O'), ('stars', 'O'), ('were', 'O'), ('clustered', 'O'), ('about', 'O'), ('his', 'O'), ('head', 'O'), (',', 'O'), ('And', 'O'), ('the', 'O'), ('earth', 'O'), ('was', 'O'), ('under', 'O'), ('his', 'O'), ('feet', 'O'), ('.', 'O')]
# Emotion: fear (Score: 0.34)
#
# Sentence: And God walked , and where he trod His footsteps hollowed the valleys out And bulged the mountains up .
# NER Tags: [('And', 'O'), ('God', 'O'), ('walked', 'O'), (',', 'O'), ('and', 'O'), ('where', 'O'), ('he', 'O'), ('trod', 'O'), ('His', 'O'), ('footsteps', 'O'), ('hollowed', 'O'), ('the', 'O'), ('valleys', 'O'), ('out', 'O'), ('And', 'O'), ('bulged', 'O'), ('the', 'O'), ('mountains', 'O'), ('up', 'O'), ('.', 'O')]
# Emotion: fear (Score: 0.53)
#
# Sentence: Then he stopped and looked and saw That the earth was hot and barren .
# NER Tags: [('Then', 'O'), ('he', 'O'), ('stopped', 'O'), ('and', 'O'), ('looked', 'O'), ('and', 'O'), ('saw', 'O'), ('That', 'O'), ('the', 'O'), ('earth', 'O'), ('was', 'O'), ('hot', 'O'), ('and', 'O'), ('barren', 'O'), ('.', 'O')]
# Emotion: disgust (Score: 0.29)
#
# Sentence: So God stepped over to the edge of the world And he spat out the seven seas— He batted his eyes , and the lightnings flashed— He clapped his hands , and the thunders rolled— And the waters above the earth came down , The cooling waters came down .
# NER Tags: [('So', 'O'), ('God', 'O'), ('stepped', 'O'), ('over', 'O'), ('to', 'O'), ('the', 'O'), ('edge', 'O'), ('of', 'O'), ('the', 'O'), ('world', 'O'), ('And', 'O'), ('he', 'O'), ('spat', 'O'), ('out', 'O'), ('the', 'O'), ('seven', 'O'), ('seas—', 'O'), ('He', 'O'), ('batted', 'O'), ('his', 'O'), ('eyes', 'O'), (',', 'O'), ('and', 'O'), ('the', 'O'), ('lightnings', 'O'), ('flashed—', 'O'), ('He', 'O'), ('clapped', 'O'), ('his', 'O'), ('hands', 'O'), (',', 'O'), ('and', 'O'), ('the', 'O'), ('thunders', 'O'), ('rolled—', 'O'), ('And', 'O'), ('the', 'O'), ('waters', 'O'), ('above', 'O'), ('the', 'O'), ('earth', 'O'), ('came', 'O'), ('down', 'O'), (',', 'O'), ('The', 'O'), ('cooling', 'O'), ('waters', 'O'), ('came', 'O'), ('down', 'O'), ('.', 'O')]
# Emotion: anger (Score: 0.42)
#
# Sentence: Then the green grass sprouted , And the little red flowers blossomed , The pine tree pointed his finger to the sky , And the oak spread out his arms , The lakes cuddled down in the hollows of the ground , And the rivers ran down to the sea ; And God smiled again , And the rainbow appeared , And curled itself around his shoulder .
# NER Tags: [('Then', 'O'), ('the', 'O'), ('green', 'O'), ('grass', 'O'), ('sprouted', 'O'), (',', 'O'), ('And', 'O'), ('the', 'O'), ('little', 'O'), ('red', 'O'), ('flowers', 'O'), ('blossomed', 'O'), (',', 'O'), ('The', 'O'), ('pine', 'O'), ('tree', 'O'), ('pointed', 'O'), ('his', 'O'), ('finger', 'O'), ('to', 'O'), ('the', 'O'), ('sky', 'O'), (',', 'O'), ('And', 'O'), ('the', 'O'), ('oak', 'O'), ('spread', 'O'), ('out', 'O'), ('his', 'O'), ('arms', 'O'), (',', 'O'), ('The', 'O'), ('lakes', 'O'), ('cuddled', 'O'), ('down', 'O'), ('in', 'O'), ('the', 'O'), ('hollows', 'O'), ('of', 'O'), ('the', 'O'), ('ground', 'O'), (',', 'O'), ('And', 'O'), ('the', 'O'), ('rivers', 'O'), ('ran', 'O'), ('down', 'O'), ('to', 'O'), ('the', 'O'), ('sea', 'O'), (';', 'O'), ('And', 'O'), ('God', 'O'), ('smiled', 'O'), ('again', 'O'), (',', 'O'), ('And', 'O'), ('the', 'O'), ('rainbow', 'O'), ('appeared', 'O'), (',', 'O'), ('And', 'O'), ('curled', 'O'), ('itself', 'O'), ('around', 'O'), ('his', 'O'), ('shoulder', 'O'), ('.', 'O')]
# Emotion: joy (Score: 0.84)
#
# Sentence: Then God raised his arm and he waved his hand Over the sea and over the land , And he said : Bring forth !
# NER Tags: [('Then', 'O'), ('God', 'O'), ('raised', 'O'), ('his', 'O'), ('arm', 'O'), ('and', 'O'), ('he', 'O'), ('waved', 'O'), ('his', 'O'), ('hand', 'O'), ('Over', 'O'), ('the', 'O'), ('sea', 'O'), ('and', 'O'), ('over', 'O'), ('the', 'O'), ('land', 'O'), (',', 'O'), ('And', 'O'), ('he', 'O'), ('said', 'O'), (':', 'O'), ('Bring', 'O'), ('forth', 'O'), ('!', 'O')]
# Emotion: anger (Score: 0.30)
#
# Sentence: Bring forth !
# NER Tags: [('Bring', 'O'), ('forth', 'O'), ('!', 'O')]
# Emotion: neutral (Score: 0.42)
#
# Sentence: And quicker than God could drop his hand , Fishes and fowls And beasts and birds Swam the rivers and the seas , Roamed the forests and the woods , And split the air with their wings .
# NER Tags: [('And', 'O'), ('quicker', 'O'), ('than', 'O'), ('God', 'O'), ('could', 'O'), ('drop', 'O'), ('his', 'O'), ('hand', 'O'), (',', 'O'), ('Fishes', 'O'), ('and', 'O'), ('fowls', 'O'), ('And', 'O'), ('beasts', 'O'), ('and', 'O'), ('birds', 'O'), ('Swam', 'O'), ('the', 'O'), ('rivers', 'O'), ('and', 'O'), ('the', 'O'), ('seas', 'O'), (',', 'O'), ('Roamed', 'O'), ('the', 'O'), ('forests', 'O'), ('and', 'O'), ('the', 'O'), ('woods', 'O'), (',', 'O'), ('And', 'O'), ('split', 'O'), ('the', 'O'), ('air', 'O'), ('with', 'O'), ('their', 'O'), ('wings', 'O'), ('.', 'O')]
# Emotion: anger (Score: 0.72)
#
# Sentence: And God said : That 's good !
# NER Tags: [('And', 'O'), ('God', 'O'), ('said', 'O'), (':', 'O'), ('That', 'O'), ("'s", 'O'), ('good', 'O'), ('!', 'O')]
# Emotion: joy (Score: 0.87)
#
# Sentence: Then God walked around , And God looked around On all that he had made .
# NER Tags: [('Then', 'O'), ('God', 'O'), ('walked', 'O'), ('around', 'O'), (',', 'O'), ('And', 'O'), ('God', 'O'), ('looked', 'O'), ('around', 'O'), ('On', 'O'), ('all', 'O'), ('that', 'O'), ('he', 'O'), ('had', 'O'), ('made', 'O'), ('.', 'O')]
# Emotion: surprise (Score: 0.50)
#
# Sentence: He looked at his sun , And he looked at his moon , And he looked at his little stars ; He looked on his world With all its living things , And God said : I 'm lonely still .
# NER Tags: [('He', 'O'), ('looked', 'O'), ('at', 'O'), ('his', 'O'), ('sun', 'O'), (',', 'O'), ('And', 'O'), ('he', 'O'), ('looked', 'O'), ('at', 'O'), ('his', 'O'), ('moon', 'O'), (',', 'O'), ('And', 'O'), ('he', 'O'), ('looked', 'O'), ('at', 'O'), ('his', 'O'), ('little', 'O'), ('stars', 'O'), (';', 'O'), ('He', 'O'), ('looked', 'O'), ('on', 'O'), ('his', 'O'), ('world', 'O'), ('With', 'O'), ('all', 'O'), ('its', 'O'), ('living', 'O'), ('things', 'O'), (',', 'O'), ('And', 'O'), ('God', 'O'), ('said', 'O'), (':', 'O'), ('I', 'O'), ("'m", 'O'), ('lonely', 'O'), ('still', 'O'), ('.', 'O')]
# Emotion: sadness (Score: 0.93)
#
# Sentence: Then God sat down— On the side of a hill where he could think ; By a deep , wide river he sat down ; With his head in his hands , God thought and thought , Till he thought : I 'll make me a man !
# NER Tags: [('Then', 'O'), ('God', 'O'), ('sat', 'O'), ('down—', 'O'), ('On', 'O'), ('the', 'O'), ('side', 'O'), ('of', 'O'), ('a', 'O'), ('hill', 'O'), ('where', 'O'), ('he', 'O'), ('could', 'O'), ('think', 'O'), (';', 'O'), ('By', 'O'), ('a', 'O'), ('deep', 'O'), (',', 'O'), ('wide', 'O'), ('river', 'O'), ('he', 'O'), ('sat', 'O'), ('down', 'O'), (';', 'O'), ('With', 'O'), ('his', 'O'), ('head', 'O'), ('in', 'O'), ('his', 'O'), ('hands', 'O'), (',', 'O'), ('God', 'O'), ('thought', 'O'), ('and', 'O'), ('thought', 'O'), (',', 'O'), ('Till', 'O'), ('he', 'O'), ('thought', 'O'), (':', 'O'), ('I', 'O'), ("'ll", 'O'), ('make', 'O'), ('me', 'O'), ('a', 'O'), ('man', 'O'), ('!', 'O')]
# Emotion: fear (Score: 0.50)
#
# Sentence: Up from the bed of the river God scooped the clay ; And by the bank of the river He kneeled him down ; And there the great God Almighty Who lit the sun and fixed it in the sky , Who flung the stars to the most far corner of the night , Who rounded the earth in the middle of his hand ; This great God , Like a mammy bending over her baby , Kneeled down in the dust Toiling over a lump of clay Till he shaped it in is his own image ; Then into it he blew the breath of life , And man became a living soul .
# NER Tags: [('Up', 'O'), ('from', 'O'), ('the', 'O'), ('bed', 'O'), ('of', 'O'), ('the', 'O'), ('river', 'O'), ('God', 'O'), ('scooped', 'O'), ('the', 'O'), ('clay', 'O'), (';', 'O'), ('And', 'O'), ('by', 'O'), ('the', 'O'), ('bank', 'O'), ('of', 'O'), ('the', 'O'), ('river', 'O'), ('He', 'O'), ('kneeled', 'O'), ('him', 'O'), ('down', 'O'), (';', 'O'), ('And', 'O'), ('there', 'O'), ('the', 'O'), ('great', 'O'), ('God', 'O'), ('Almighty', 'O'), ('Who', 'O'), ('lit', 'O'), ('the', 'O'), ('sun', 'O'), ('and', 'O'), ('fixed', 'O'), ('it', 'O'), ('in', 'O'), ('the', 'O'), ('sky', 'O'), (',', 'O'), ('Who', 'O'), ('flung', 'O'), ('the', 'O'), ('stars', 'O'), ('to', 'O'), ('the', 'O'), ('most', 'O'), ('far', 'O'), ('corner', 'O'), ('of', 'O'), ('the', 'O'), ('night', 'O'), (',', 'O'), ('Who', 'O'), ('rounded', 'O'), ('the', 'O'), ('earth', 'O'), ('in', 'O'), ('the', 'O'), ('middle', 'O'), ('of', 'O'), ('his', 'O'), ('hand', 'O'), (';', 'O'), ('This', 'O'), ('great', 'O'), ('God', 'O'), (',', 'O'), ('Like', 'O'), ('a', 'O'), ('mammy', 'O'), ('bending', 'O'), ('over', 'O'), ('her', 'O'), ('baby', 'O'), (',', 'O'), ('Kneeled', 'O'), ('down', 'O'), ('in', 'O'), ('the', 'O'), ('dust', 'O'), ('Toiling', 'O'), ('over', 'O'), ('a', 'O'), ('lump', 'O'), ('of', 'O'), ('clay', 'O'), ('Till', 'O'), ('he', 'O'), ('shaped', 'O'), ('it', 'O'), ('in', 'O'), ('is', 'O'), ('his', 'O'), ('own', 'O'), ('image', 'O'), (';', 'O'), ('Then', 'O'), ('into', 'O'), ('it', 'O'), ('he', 'O'), ('blew', 'O'), ('the', 'O'), ('breath', 'O'), ('of', 'O'), ('life', 'O'), (',', 'O'), ('And', 'O'), ('man', 'O'), ('became', 'O'), ('a', 'O'), ('living', 'O'), ('soul', 'O'), ('.', 'O')]
# Emotion: disgust (Score: 0.36)
#
# Sentence: Amen .
# NER Tags: [('Amen', 'O'), ('.', 'O')]
# Emotion: anger (Score: 0.46)
#
# Sentence: Amen .
# NER Tags: [('Amen', 'O'), ('.', 'O')]
# Emotion: anger (Score: 0.46)
#
# ["And God stepped out on space , And he looked around and said : I 'm lonely— I 'll make me a world .", 'And far as the eye of God could see Darkness covered everything , Blacker than a hundred midnights Down in a cypress swamp .', "Then God smiled , And the light broke , And the darkness rolled up on one side , And the light stood shining on the other , And God said : That 's good !", 'Then God reached out and took the light in his hands , And God rolled the light around in his hands Until he made the sun ; And he set that sun a-blazing in the heavens .', 'And the light that was left from making the sun God gathered it up in a shining ball And flung it against the darkness , Spangling the night with the moon and stars .', "Then down between The darkness and the light He hurled the world ; And God said : That 's good !", 'Then God himself stepped down— And the sun was on his right hand , And the moon was on his left ; The stars were clustered about his head , And the earth was under his feet . And God walked , and where he trod His footsteps hollowed the valleys out And bulged the mountains up .', 'Then he stopped and looked and saw That the earth was hot and barren .', 'So God stepped over to the edge of the world And he spat out the seven seas— He batted his eyes , and the lightnings flashed— He clapped his hands , and the thunders rolled— And the waters above the earth came down , The cooling waters came down .', 'Then the green grass sprouted , And the little red flowers blossomed , The pine tree pointed his finger to the sky , And the oak spread out his arms , The lakes cuddled down in the hollows of the ground , And the rivers ran down to the sea ; And God smiled again , And the rainbow appeared , And curled itself around his shoulder .', 'Then God raised his arm and he waved his hand Over the sea and over the land , And he said : Bring forth !', 'Bring forth !', 'And quicker than God could drop his hand , Fishes and fowls And beasts and birds Swam the rivers and the seas , Roamed the forests and the woods , And split the air with their wings .', "And God said : That 's good !", 'Then God walked around , And God looked around On all that he had made .', "He looked at his sun , And he looked at his moon , And he looked at his little stars ; He looked on his world With all its living things , And God said : I 'm lonely still .", "Then God sat down— On the side of a hill where he could think ; By a deep , wide river he sat down ; With his head in his hands , God thought and thought , Till he thought : I 'll make me a man !", 'Up from the bed of the river God scooped the clay ; And by the bank of the river He kneeled him down ; And there the great God Almighty Who lit the sun and fixed it in the sky , Who flung the stars to the most far corner of the night , Who rounded the earth in the middle of his hand ; This great God , Like a mammy bending over her baby , Kneeled down in the dust Toiling over a lump of clay Till he shaped it in is his own image ; Then into it he blew the breath of life , And man became a living soul .', 'Amen . Amen .']
#
# [{'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': {'Blacker'}, 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}]
#
# ['sadness', 'fear', 'joy', 'anger', 'sadness', 'joy', 'fear', 'disgust', 'anger', 'joy', 'anger', 'neutral', 'anger', 'joy', 'surprise', 'sadness', 'fear', 'disgust', 'anger']
# Sentence: If all the world and love were young , And truth in every Shepherd ’ s tongue , These pretty pleasures might me move , To live with thee , and be thy love .
# NER Tags: [('If', 'O'), ('all', 'O'), ('the', 'O'), ('world', 'O'), ('and', 'O'), ('love', 'O'), ('were', 'O'), ('young', 'O'), (',', 'O'), ('And', 'O'), ('truth', 'O'), ('in', 'O'), ('every', 'O'), ('Shepherd', 'O'), ('’', 'O'), ('s', 'O'), ('tongue', 'O'), (',', 'O'), ('These', 'O'), ('pretty', 'O'), ('pleasures', 'O'), ('might', 'O'), ('me', 'O'), ('move', 'O'), (',', 'O'), ('To', 'O'), ('live', 'O'), ('with', 'O'), ('thee', 'O'), (',', 'O'), ('and', 'O'), ('be', 'O'), ('thy', 'O'), ('love', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.49)
#
# Sentence: Time drives the flocks from field to fold , When Rivers rage and Rocks grow cold , And Philomel becometh dumb , The rest complains of cares to come .
# NER Tags: [('Time', 'O'), ('drives', 'O'), ('the', 'O'), ('flocks', 'O'), ('from', 'O'), ('field', 'O'), ('to', 'O'), ('fold', 'O'), (',', 'O'), ('When', 'O'), ('Rivers', 'O'), ('rage', 'O'), ('and', 'O'), ('Rocks', 'O'), ('grow', 'O'), ('cold', 'O'), (',', 'O'), ('And', 'O'), ('Philomel', 'PERSON'), ('becometh', 'O'), ('dumb', 'O'), (',', 'O'), ('The', 'O'), ('rest', 'O'), ('complains', 'O'), ('of', 'O'), ('cares', 'O'), ('to', 'O'), ('come', 'O'), ('.', 'O')]
# Emotion: anger (Score: 0.98)
#
# Sentence: The flowers do fade , and wanton fields , To wayward winter reckoning yields , A honey tongue , a heart of gall , Is fancy ’ s spring , but sorrow ’ s fall .
# NER Tags: [('The', 'O'), ('flowers', 'O'), ('do', 'O'), ('fade', 'O'), (',', 'O'), ('and', 'O'), ('wanton', 'O'), ('fields', 'O'), (',', 'O'), ('To', 'O'), ('wayward', 'O'), ('winter', 'O'), ('reckoning', 'O'), ('yields', 'O'), (',', 'O'), ('A', 'O'), ('honey', 'O'), ('tongue', 'O'), (',', 'O'), ('a', 'O'), ('heart', 'O'), ('of', 'O'), ('gall', 'O'), (',', 'O'), ('Is', 'O'), ('fancy', 'O'), ('’', 'O'), ('s', 'O'), ('spring', 'O'), (',', 'O'), ('but', 'O'), ('sorrow', 'O'), ('’', 'O'), ('s', 'O'), ('fall', 'O'), ('.', 'O')]
# Emotion: sadness (Score: 0.99)
#
# Sentence: Thy gowns , thy shoes , thy beds of Roses , Thy cap , thy kirtle , and thy posies Soon break , soon wither , soon forgotten : In folly ripe , in reason rotten .
# ...
#
# [{'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': {'Philomel'}, 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}]
#
# ['neutral', 'anger', 'sadness', 'neutral', 'joy']
# Sentence: I marvel how Nature could ever find space For so many strange contrasts in one human face : There 's thought and no thought , and there 's paleness and bloom And bustle and sluggishness , pleasure and gloom .
# NER Tags: [('I', 'O'), ('marvel', 'O'), ('how', 'O'), ('Nature', 'O'), ('could', 'O'), ('ever', 'O'), ('find', 'O'), ('space', 'O'), ('For', 'O'), ('so', 'O'), ('many', 'O'), ('strange', 'O'), ('contrasts', 'O'), ('in', 'O'), ('one', 'O'), ('human', 'O'), ('face', 'O'), (':', 'O'), ('There', 'O'), ("'s", 'O'), ('thought', 'O'), ('and', 'O'), ('no', 'O'), ('thought', 'O'), (',', 'O'), ('and', 'O'), ('there', 'O'), ("'s", 'O'), ('paleness', 'O'), ('and', 'O'), ('bloom', 'O'), ('And', 'O'), ('bustle', 'O'), ('and', 'O'), ('sluggishness', 'O'), (',', 'O'), ('pleasure', 'O'), ('and', 'O'), ('gloom', 'O'), ('.', 'O')]
# Emotion: surprise (Score: 0.93)
#
# Sentence: There 's weakness , and strength both redundant and vain ; Such strength as , if ever affliction and pain Could pierce through a temper that 's soft to disease , Would be rational peace -- a philosopher 's ease .
# NER Tags: [('There', 'O'), ("'s", 'O'), ('weakness', 'O'), (',', 'O'), ('and', 'O'), ('strength', 'O'), ('both', 'O'), ('redundant', 'O'), ('and', 'O'), ('vain', 'O'), (';', 'O'), ('Such', 'O'), ('strength', 'O'), ('as', 'O'), (',', 'O'), ('if', 'O'), ('ever', 'O'), ('affliction', 'O'), ('and', 'O'), ('pain', 'O'), ('Could', 'O'), ('pierce', 'O'), ('through', 'O'), ('a', 'O'), ('temper', 'O'), ('that', 'O'), ("'s", 'O'), ('soft', 'O'), ('to', 'O'), ('disease', 'O'), (',', 'O'), ('Would', 'O'), ('be', 'O'), ('rational', 'O'), ('peace', 'O'), ('--', 'O'), ('a', 'O'), ('philosopher', 'O'), ("'s", 'O'), ('ease', 'O'), ('.', 'O')]
# Emotion: sadness (Score: 0.92)
#
# Sentence: There 's indifference , alike when he fails or succeeds , And attention full ten times as much as there needs ; Pride where there 's no envy , there 's so much of joy ; And mildness , and spirit both forward and coy .
# NER Tags: [('There', 'O'), ("'s", 'O'), ('indifference', 'O'), (',', 'O'), ('alike', 'O'), ('when', 'O'), ('he', 'O'), ('fails', 'O'), ('or', 'O'), ('succeeds', 'O'), (',', 'O'), ('And', 'O'), ('attention', 'O'), ('full', 'O'), ('ten', 'O'), ('times', 'O'), ('as', 'O'), ('much', 'O'), ('as', 'O'), ('there', 'O'), ('needs', 'O'), (';', 'O'), ('Pride', 'O'), ('where', 'O'), ('there', 'O'), ("'s", 'O'), ('no', 'O'), ('envy', 'O'), (',', 'O'), ('there', 'O'), ("'s", 'O'), ('so', 'O'), ('much', 'O'), ('of', 'O'), ('joy', 'O'), (';', 'O'), ('And', 'O'), ('mildness', 'O'), (',', 'O'), ('and', 'O'), ('spirit', 'O'), ('both', 'O'), ('forward', 'O'), ('and', 'O'), ('coy', 'O'), ('.', 'O')]
# Emotion: joy (Score: 0.89)
#
# Sentence: There 's freedom , and sometimes a diffident stare Of shame scarcely seeming to know that she 's there , There 's virtue , the title it surely may claim , Yet wants heaven knows what to be worthy the name .
# NER Tags: [('There', 'O'), ("'s", 'O'), ('freedom', 'O'), (',', 'O'), ('and', 'O'), ('sometimes', 'O'), ('a', 'O'), ('diffident', 'O'), ('stare', 'O'), ('Of', 'O'), ('shame', 'O'), ('scarcely', 'O'), ('seeming', 'O'), ('to', 'O'), ('know', 'O'), ('that', 'O'), ('she', 'O'), ("'s", 'O'), ('there', 'O'), (',', 'O'), ('There', 'O'), ("'s", 'O'), ('virtue', 'O'), (',', 'O'), ('the', 'O'), ('title', 'O'), ('it', 'O'), ('surely', 'O'), ('may', 'O'), ('claim', 'O'), (',', 'O'), ('Yet', 'O'), ('wants', 'O'), ('heaven', 'O'), ('knows', 'O'), ('what', 'O'), ('to', 'O'), ('be', 'O'), ('worthy', 'O'), ('the', 'O'), ('name', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.69)
#
# Sentence: This picture from nature may seem to depart , Yet the Man would at once run away with your heart ; And I for five centuries right gladly would be Such an odd such a kind happy creature as he .
# NER Tags: [('This', 'O'), ('picture', 'O'), ('from', 'O'), ('nature', 'O'), ('may', 'O'), ('seem', 'O'), ('to', 'O'), ('depart', 'O'), (',', 'O'), ('Yet', 'O'), ('the', 'O'), ('Man', 'O'), ('would', 'O'), ('at', 'O'), ('once', 'O'), ('run', 'O'), ('away', 'O'), ('with', 'O'), ('your', 'O'), ('heart', 'O'), (';', 'O'), ('And', 'O'), ('I', 'O'), ('for', 'O'), ('five', 'O'), ('centuries', 'O'), ('right', 'O'), ('gladly', 'O'), ('would', 'O'), ('be', 'O'), ('Such', 'O'), ('an', 'O'), ('odd', 'O'), ('such', 'O'), ('a', 'O'), ('kind', 'O'), ('happy', 'O'), ('creature', 'O'), ('as', 'O'), ('he', 'O'), ('.', 'O')]
# Emotion: joy (Score: 0.66)
#
# ["I marvel how Nature could ever find space For so many strange contrasts in one human face : There 's thought and no thought , and there 's paleness and bloom And bustle and sluggishness , pleasure and gloom .", "There 's weakness , and strength both redundant and vain ; Such strength as , if ever affliction and pain Could pierce through a temper that 's soft to disease , Would be rational peace -- a philosopher 's ease .", "There 's indifference , alike when he fails or succeeds , And attention full ten times as much as there needs ; Pride where there 's no envy , there 's so much of joy ; And mildness , and spirit both forward and coy .", "There 's freedom , and sometimes a diffident stare Of shame scarcely seeming to know that she 's there , There 's virtue , the title it surely may claim , Yet wants heaven knows what to be worthy the name .", 'This picture from nature may seem to depart , Yet the Man would at once run away with your heart ; And I for five centuries right gladly would be Such an odd such a kind happy creature as he .']
#
# [{'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}]
#
# ['surprise', 'sadness', 'joy', 'neutral', 'joy']
# Sentence: She kept an antique shop – or it kept her .
# NER Tags: [('She', 'O'), ('kept', 'O'), ('an', 'O'), ('antique', 'O'), ('shop', 'O'), ('–', 'O'), ('or', 'O'), ('it', 'O'), ('kept', 'O'), ('her', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.85)
#
# Sentence: Among Apostle spoons and Bristol glass , The faded silks , the heavy furniture , She watched her own reflection in the brass Salvers and silver bowls , as if to prove Polish was all , there was no need of love .
# NER Tags: [('Among', 'O'), ('Apostle', 'O'), ('spoons', 'O'), ('and', 'O'), ('Bristol', 'LOCATION'), ('glass', 'O'), (',', 'O'), ('The', 'O'), ('faded', 'O'), ('silks', 'O'), (',', 'O'), ('the', 'O'), ('heavy', 'O'), ('furniture', 'O'), (',', 'O'), ('She', 'O'), ('watched', 'O'), ('her', 'O'), ('own', 'O'), ('reflection', 'O'), ('in', 'O'), ('the', 'O'), ('brass', 'O'), ('Salvers', 'O'), ('and', 'O'), ('silver', 'O'), ('bowls', 'O'), (',', 'O'), ('as', 'O'), ('if', 'O'), ('to', 'O'), ('prove', 'O'), ('Polish', 'O'), ('was', 'O'), ('all', 'O'), (',', 'O'), ('there', 'O'), ('was', 'O'), ('no', 'O'), ('need', 'O'), ('of', 'O'), ('love', 'O'), ('.', 'O')]
# Emotion: sadness (Score: 0.48)
#
# Sentence: And I remember how I once refused To go out with her , since I was afraid .
# NER Tags: [('And', 'O'), ('I', 'O'), ('remember', 'O'), ('how', 'O'), ('I', 'O'), ('once', 'O'), ('refused', 'O'), ('To', 'O'), ('go', 'O'), ('out', 'O'), ('with', 'O'), ('her', 'O'), (',', 'O'), ('since', 'O'), ('I', 'O'), ('was', 'O'), ('afraid', 'O'), ('.', 'O')]
# Emotion: fear (Score: 0.98)
#
# Sentence: It was perhaps a wish not to be used Like antique objects .
# NER Tags: [('It', 'O'), ('was', 'O'), ('perhaps', 'O'), ('a', 'O'), ('wish', 'O'), ('not', 'O'), ('to', 'O'), ('be', 'O'), ('used', 'O'), ('Like', 'O'), ('antique', 'O'), ('objects', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.70)
#
# Sentence: Though she never said That she was hurt , I still could feel the guilt Of that refusal , guessing how she felt .
# NER Tags: [('Though', 'O'), ('she', 'O'), ('never', 'O'), ('said', 'O'), ('That', 'O'), ('she', 'O'), ('was', 'O'), ('hurt', 'O'), (',', 'O'), ('I', 'O'), ('still', 'O'), ('could', 'O'), ('feel', 'O'), ('the', 'O'), ('guilt', 'O'), ('Of', 'O'), ('that', 'O'), ('refusal', 'O'), (',', 'O'), ('guessing', 'O'), ('how', 'O'), ('she', 'O'), ('felt', 'O'), ('.', 'O')]
# Emotion: sadness (Score: 0.79)
#
# Sentence: Later , too frail to keep a shop , she put All her best things in one narrow room .
# NER Tags: [('Later', 'O'), (',', 'O'), ('too', 'O'), ('frail', 'O'), ('to', 'O'), ('keep', 'O'), ('a', 'O'), ('shop', 'O'), (',', 'O'), ('she', 'O'), ('put', 'O'), ('All', 'O'), ('her', 'O'), ('best', 'O'), ('things', 'O'), ('in', 'O'), ('one', 'O'), ('narrow', 'O'), ('room', 'O'), ('.', 'O')]
# Emotion: sadness (Score: 0.47)
#
# Sentence: The place smelt old , of things too long kept shut , The smell of absences where shadows come That can ’ t be polished .
# NER Tags: [('The', 'O'), ('place', 'O'), ('smelt', 'O'), ('old', 'O'), (',', 'O'), ('of', 'O'), ('things', 'O'), ('too', 'O'), ('long', 'O'), ('kept', 'O'), ('shut', 'O'), (',', 'O'), ('The', 'O'), ('smell', 'O'), ('of', 'O'), ('absences', 'O'), ('where', 'O'), ('shadows', 'O'), ('come', 'O'), ('That', 'O'), ('can', 'O'), ('’', 'O'), ('t', 'O'), ('be', 'O'), ('polished', 'O'), ('.', 'O')]
# Emotion: sadness (Score: 0.52)
#
# Sentence: There was nothing then To give her own reflection back again .
# NER Tags: [('There', 'O'), ('was', 'O'), ('nothing', 'O'), ('then', 'O'), ('To', 'O'), ('give', 'O'), ('her', 'O'), ('own', 'O'), ('reflection', 'O'), ('back', 'O'), ('again', 'O'), ('.', 'O')]
# Emotion: neutral (Score: 0.33)
#
# Sentence: And when she died I felt no grief at all , Only the guilt of what I once refused .
# NER Tags: [('And', 'O'), ('when', 'O'), ('she', 'O'), ('died', 'O'), ('I', 'O'), ('felt', 'O'), ('no', 'O'), ('grief', 'O'), ('at', 'O'), ('all', 'O'), (',', 'O'), ('Only', 'O'), ('the', 'O'), ('guilt', 'O'), ('of', 'O'), ('what', 'O'), ('I', 'O'), ('once', 'O'), ('refused', 'O'), ('.', 'O')]
# Emotion: sadness (Score: 0.99)
#
# Sentence: I walked into her room among the tall Sideboards and cupboards – things she never used But needed ; and no finger marks were there , Only the new dust falling through the air .
# NER Tags: [('I', 'O'), ('walked', 'O'), ('into', 'O'), ('her', 'O'), ('room', 'O'), ('among', 'O'), ('the', 'O'), ('tall', 'O'), ('Sideboards', 'O'), ('and', 'O'), ('cupboards', 'O'), ('–', 'O'), ('things', 'O'), ('she', 'O'), ('never', 'O'), ('used', 'O'), ('But', 'O'), ('needed', 'O'), (';', 'O'), ('and', 'O'), ('no', 'O'), ('finger', 'O'), ('marks', 'O'), ('were', 'O'), ('there', 'O'), (',', 'O'), ('Only', 'O'), ('the', 'O'), ('new', 'O'), ('dust', 'O'), ('falling', 'O'), ('through', 'O'), ('the', 'O'), ('air', 'O'), ('.', 'O')]
# Emotion: surprise (Score: 0.33)
#
# ['She kept an antique shop – or it kept her .', 'Among Apostle spoons and Bristol glass , The faded silks , the heavy furniture , She watched her own reflection in the brass Salvers and silver bowls , as if to prove Polish was all , there was no need of love .', 'And I remember how I once refused To go out with her , since I was afraid .', 'It was perhaps a wish not to be used Like antique objects .', 'Though she never said That she was hurt , I still could feel the guilt Of that refusal , guessing how she felt . Later , too frail to keep a shop , she put All her best things in one narrow room . The place smelt old , of things too long kept shut , The smell of absences where shadows come That can ’ t be polished .', 'There was nothing then To give her own reflection back again .', 'And when she died I felt no grief at all , Only the guilt of what I once refused .', 'I walked into her room among the tall Sideboards and cupboards – things she never used But needed ; and no finger marks were there , Only the new dust falling through the air .']
#
# [{'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': {'Bristol'}}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}, {'PERSON': set(), 'ORGANIZATION': set(), 'LOCATION': set()}]
#
# ['neutral', 'sadness', 'fear', 'neutral', 'sadness', 'neutral', 'sadness', 'surprise']
# Sentence: Swiftly walk o'er the western wave , Spirit of Night !
# NER Tags: [('Swiftly', 'O'), ('walk', 'O'), ("o'er", 'O'), ('the', 'O'), ('western', 'O'), ('wave', 'O'), (',', 'O'), ('Spirit', 'O'), ('of', 'O'), ('Night', 'O'), ('!', 'O')]
# Emotion: fear (Score: 0.52)
#
# Sentence: Out of the misty eastern cave , Where , all the long and lone daylight , Thou wovest dreams of joy and fear , Which make thee terrible and dear , — Swift be thy flight !
# NER Tags: [('Out', 'O'), ('of', 'O'), ('the', 'O'), ('misty', 'O'), ('eastern', 'O'), ('cave', 'O'), (',', 'O'), ('Where', 'O'), (',', 'O'), ('all', 'O'), ('the', 'O'), ('long', 'O'), ('and', 'O'), ('lone', 'O'), ('daylight', 'O'), (',', 'O'), ('Thou', 'O'), ('wovest', 'O'), ('dreams', 'O'), ('of', 'O'), ('joy', 'O'), ('and', 'O'), ('fear', 'O'), (',', 'O'), ('Which', 'O'), ('make', 'O'), ('thee', 'O'), ('terrible', 'O'), ('and', 'O'), ('dear', 'O'), (',', 'O'), ('—', 'O'), ('Swift', 'O'), ('be', 'O'), ('thy', 'O'), ('flight', 'O'), ('!', 'O')]
# Emotion: fear (Score: 0.98)
#
# Sentence: Wrap thy form in a mantle gray , Star-inwrought !
# NER Tags: [('Wrap', 'O'), ('thy', 'O'), ('form', 'O'), ('in', 'O'), ('a', 'O'), ('mantle', 'O'), ('gray', 'O'), (',', 'O'), ('Star-inwrought', 'O'), ('!', 'O')]
# Emotion: anger (Score: 0.59)
#
# Sentence: Blind with thine hair the eyes of Day ; Kiss her until she be wearied out , Then wander o'er city , and sea , and land , Touching all with thine opiate wand— Come , long-sought !
# NER Tags: [('Blind', 'O'), ('with', 'O'), ('thine', 'O'), ('hair', 'O'), ('the', 'O'), ('eyes', 'O'), ('of', 'O'), ('Day', 'O'), (';', 'O'), ('Kiss', 'O'), ('her', 'O'), ('until', 'O'), ('she', 'O'), ('be', 'O'), ('wearied', 'O'), ('out', 'O'), (',', 'O'), ('Then', 'O'), ('wander', 'O'), ("o'er", 'O'), ('city', 'O'), (',', 'O'), ('and', 'O'), ('sea', 'O'), (',', 'O'), ('and', 'O'), ('land', 'O'), (',', 'O'), ('Touching', 'O'), ('all', 'O'), ('with', 'O'), ('thine', 'O'), ('opiate', 'O'), ('wand—', 'O'), ('Come', 'O'), (',', 'O'), ('long-sought', 'O'), ('!', 'O')]
# Emotion: sadness (Score: 0.42)
#
# Sentence: When I arose and saw the dawn , I sighed for thee ; When light rode high , and the dew was gone , And noon lay heavy on flower and tree , And the weary Day turned to his rest , Lingering like an unloved guest .
# NER Tags: [('When', 'O'), ('I', 'O'), ('arose', 'O'), ('and', 'O'), ('saw', 'O'), ('the', 'O'), ('dawn', 'O'), (',', 'O'), ('I', 'O'), ('sighed', 'O'), ('for', 'O'), ('thee', 'O'), (';', 'O'), ('When', 'O'), ('light', 'O'), ('rode', 'O'), ('high', 'O'), (',', 'O'), ('and', 'O'), ('the', 'O'), ('dew', 'O'), ('was', 'O'), ('gone', 'O'), (',', 'O'), ('And', 'O'), ('noon', 'O'), ('lay', 'O'), ('heavy', 'O'), ('on', 'O'), ('flower', 'O'), ('and', 'O'), ('tree', 'O'), (',', 'O'), ('And', 'O'), ('the', 'O'), ('weary', 'O'), ('Day', 'O'), ('turned', 'O'), ('to', 'O'), ('his', 'O'), ('rest', 'O'), (',', 'O'), ('Lingering', 'O'), ('like', 'O'), ('an', 'O'), ('unloved', 'O'), ('guest', 'O'), ('.', 'O')]
# Emotion: sadness (Score: 0.99)
#
# Sentence: I sighed for thee .
# NER Tags: [('I', 'O'), ('sighed', 'O'), ('for', 'O'), ('thee', 'O'), ('.', 'O')]
# Emotion: sadness (Score: 0.96)
